# %%
import pickle
import sys
import matplotlib.pyplot as plt
import numpy as np
import networkx as nx
import pandas as pd
import random
from functions import *

# %%
with open('empirical_networks.pkl', 'rb') as f:
    empirical_networks = pickle.load(f)
    
with open('BA_networks.pkl', 'rb') as f:
    BA_networks = pickle.load(f)

# %%
qs = np.arange(0.01,1, 0.01).round(2)

# %%
plt.plot(qs, empirical_networks['physician_trust']['friend']['props'], label="friend")
plt.plot(qs, empirical_networks['physician_trust']['pair']['props'], label="pair")
plt.plot(qs, empirical_networks['physician_trust']['random']['props'], label="random")
plt.xlabel("q")
plt.ylabel("proportion adopted")
plt.legend()
plt.show()

# %%
data = pd.DataFrame(columns=["seeding_method", "q", "proportion_adopted"])

for seeding_method in ["random", "pair", "friend"]:
    for i in range(len(qs)):
        data = pd.concat([data, pd.DataFrame({"seeding_method": [seeding_method],
                                              "q": [qs[i]],
                                              "proportion_adopted": [empirical_networks["physician_trust"][seeding_method]["props"][i]]})],
                        ignore_index=True)

# %%
# Out:
#     seeding_method     q  proportion_adopted
# 0           random  0.01            0.885477
# 1           random  0.02            0.885477
# 2           random  0.03            0.900000
# 3           random  0.04            0.900000
# 4           random  0.05            0.900000
# ..             ...   ...                 ...
# 292         friend  0.95            0.002490
# 293         friend  0.96            0.001660
# 294         friend  0.97            0.001245
# 295         friend  0.98            0.001660
# 296         friend  0.99            0.002075
#
# [297 rows x 3 columns]

# %%
data.to_csv("figure_11.csv")

# %%
empirical_networks['physician_trust']
# Out:
# {'random': {'props': array([ 8.85477178e-01,  8.85477178e-01,  9.00000000e-01,  9.00000000e-01,
#           9.00000000e-01,  9.00000000e-01,  9.00000000e-01,  9.00000000e-01,
#           9.00000000e-01,  8.83402490e-01,  9.00000000e-01,  9.00000000e-01,
#           9.00000000e-01,  8.86307054e-01,  9.00000000e-01,  9.00000000e-01,
#           8.85477178e-01,  8.80912863e-01,  8.33195021e-01,  8.72199170e-01,
#           8.17842324e-01,  8.26556017e-01,  7.92116183e-01,  8.30290456e-01,
#           6.64730290e-01,  6.14937759e-01,  6.87136929e-01,  5.87136929e-01,
#           4.90456432e-01,  5.21576763e-01,  4.98340249e-01,  4.31120332e-01,
#           5.31950207e-01,  2.04149378e-01,  1.79668050e-01,  1.10788382e-01,
#           1.70539419e-01,  8.79668050e-02,  1.02489627e-01,  2.24066390e-02,
#           2.65560166e-02,  3.60995851e-02,  2.57261411e-02,  2.36514523e-02,
#           3.15352697e-02,  2.28215768e-02,  2.82157676e-02,  1.65975104e-02,
#           2.78008299e-02,  4.97925311e-03,  1.65975104e-03,  4.97925311e-03,
#           7.05394191e-03,  4.14937759e-03,  2.07468880e-03,  3.31950207e-03,
#           2.48962656e-03,  3.73443983e-03,  3.73443983e-03,  2.48962656e-03,
#           2.07468880e-03,  4.14937759e-04,  1.24481328e-03,  1.65975104e-03,
#           1.65975104e-03,  8.29875519e-04, -1.38777878e-17,  1.24481328e-03,
#           8.29875519e-04,  8.29875519e-04,  1.24481328e-03, -1.38777878e-17,
#           2.90456432e-03,  1.65975104e-03,  4.14937759e-04, -4.14937759e-04,
#           8.29875519e-04,  8.29875519e-04, -4.14937759e-04, -1.38777878e-17,
#          -1.38777878e-17, -1.38777878e-17,  1.24481328e-03,  1.65975104e-03,
#          -4.14937759e-04, -4.14937759e-04,  4.14937759e-04,  1.24481328e-03,
#           6.05809129e-02,  5.06224066e-02,  6.34854772e-02,  5.85062241e-02,
#           6.14107884e-02,  8.71369295e-03,  1.03734440e-02,  1.24481328e-02,
#           1.16182573e-02,  7.05394191e-03,  9.95850622e-03,  1.03734440e-02,
#           9.12863071e-03,  9.95850622e-03,  8.29875519e-03,  5.39419087e-03,
#           3.31950207e-03,  4.97925311e-03,  4.56431535e-03,  2.90456432e-03,
#           6.63900415e-03,  2.48962656e-03,  2.07468880e-03,  2.07468880e-03,
#           1.65975104e-03,  2.90456432e-03,  8.29875519e-04,  2.48962656e-03,
#           1.65975104e-03,  8.29875519e-04,  1.65975104e-03,  8.29875519e-04,
#           8.29875519e-04,  8.29875519e-04,  4.14937759e-04,  2.07468880e-03,
#           1.24481328e-03,  8.29875519e-04,  8.29875519e-04,  8.29875519e-04,
#           2.07468880e-03,  1.65975104e-03,  2.07468880e-03,  4.14937759e-04,
#           1.65975104e-03,  8.29875519e-04,  1.24481328e-03,  4.14937759e-04,
#           4.14937759e-04, -4.14937759e-04,  2.48962656e-03,  1.65975104e-03,
#           1.24481328e-03,  1.65975104e-03,  2.07468880e-03]),
#   'crit_q': 0.5},
#  'N': 241}

# %%
data = pd.DataFrame(columns=["version", "network", "N", "seeding_method", "critical_q"])

for network in empirical_networks:
    for seeding_method in ["random", "pair", "friend"]:
        data = pd.concat([data, pd.DataFrame({"version": "empirical",
                                              "network": [network],
                                              "N": [empirical_networks[network]["N"]],
                                              "seeding_method": [seeding_method],
                                              "critical_q": [empirical_networks[network][seeding_method]["crit_q"]]})],
                        ignore_index=True)
        
for network in BA_networks:
    for seeding_method in ["random", "pair", "friend"]:
        data = pd.concat([data, pd.DataFrame({"version": "BA",
                                              "network": [network],
                                              "N": [BA_networks[network]["N"]],
                                              "seeding_method": [seeding_method],
                                              "critical_q": [BA_networks[network][seeding_method]["crit_q"]]})],
                        ignore_index=True)
        
data = data.sort_values(by=["N"], ignore_index=True)

# %%
plt.plot(data[(data["version"] == "empirical") & (data["seeding_method"] == "friend")]["N"],
         data[(data["version"] == "empirical") & (data["seeding_method"] == "friend")]["critical_q"],
         label="friend")

plt.plot(data[(data["version"] == "empirical") & (data["seeding_method"] == "pair")]["N"],
         data[(data["version"] == "empirical") & (data["seeding_method"] == "pair")]["critical_q"],
         label="pair")

plt.plot(data[(data["version"] == "empirical") & (data["seeding_method"] == "random")]["N"],
         data[(data["version"] == "empirical") & (data["seeding_method"] == "random")]["critical_q"],
         label="random")

plt.xlabel("N")
plt.ylabel("critical q")
plt.title("Empirical")
plt.legend()
plt.show()

# %%
plt.plot(data[(data["version"] == "BA") & (data["seeding_method"] == "friend")]["N"],
         data[(data["version"] == "BA") & (data["seeding_method"] == "friend")]["critical_q"],
         label="friend")

plt.plot(data[(data["version"] == "BA") & (data["seeding_method"] == "pair")]["N"],
         data[(data["version"] == "BA") & (data["seeding_method"] == "pair")]["critical_q"],
         label="pair")

plt.plot(data[(data["version"] == "BA") & (data["seeding_method"] == "random")]["N"],
         data[(data["version"] == "BA") & (data["seeding_method"] == "random")]["critical_q"],
         label="random")

plt.xlabel("N")
plt.ylabel("critical q")
plt.title("Barabási–Albert")
plt.legend()
plt.show()
