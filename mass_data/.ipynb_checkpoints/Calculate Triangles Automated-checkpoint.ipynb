# %%
import pandas as pd
import glob
import networkx as nx
from functions import *
import os

# %%
path = "less_than_1500_nodes"
[x.replace("{}\\".format(path), "") for x in glob.glob("{}/*".format(path))]
# Out:
# ['7th_graders',
#  'bt.csv',
#  'email_company',
#  'fb_friends.csv',
#  'high_tech_company',
#  'Karate',
#  'kidnappings',
#  'kor.2015.mers.1.00',
#  'law_firm',
#  'moreno_taro',
#  'physician_trust',
#  'sgp.2003.sars.1.00',
#  'swingers',
#  'uni_email',
#  'usa.2009.flu.1.00',
#  'usa.2020.covid.6.00']

# %%
data_paths = [x.replace("{}\\".format(path), "") for x in glob.glob("{}/*".format(path))]

# %%
G_list = []
for d_path in data_paths:
    print(d_path)
    if any(fname.endswith('.csv') for fname in  glob.glob('{}/{}/*'.format(path,d_path))):
        df = pd.read_csv('{}/{}/edges.csv'.format(path,d_path))
        G = nx.from_pandas_edgelist(df, "# source", " target")
        
    elif not any(fname.endswith('txt.gz') for fname in  glob.glob('{}/{}/*'.format(path,d_path))):
        G = nx.read_adjlist("{}/{}/edges.txt".format(path, d_path, nodetype=int))

    else:
        G = nx.read_adjlist(gzip.open('{}/{}/edges.txt.gz'.format(path,d_path)), nodetype=int)
            
    G_list.append(G)
# Out:
# 7th_graders
# bt.csv
# email_company
# fb_friends.csv
# high_tech_company
# Karate
# kidnappings
# kor.2015.mers.1.00
# law_firm
# moreno_taro
# physician_trust
# sgp.2003.sars.1.00
# swingers
# uni_email
# usa.2009.flu.1.00
# usa.2020.covid.6.00

# %%
G_list
# Out:
# [<networkx.classes.graph.Graph at 0x1b326b2c250>,
#  <networkx.classes.graph.Graph at 0x1b326b2c970>,
#  <networkx.classes.graph.Graph at 0x1b326b2ce80>,
#  <networkx.classes.graph.Graph at 0x1b327b0d640>,
#  <networkx.classes.graph.Graph at 0x1b327b0d5b0>,
#  <networkx.classes.graph.Graph at 0x1b326b225e0>,
#  <networkx.classes.graph.Graph at 0x1b32973e490>,
#  <networkx.classes.graph.Graph at 0x1b329432640>,
#  <networkx.classes.graph.Graph at 0x1b32972cdf0>,
#  <networkx.classes.graph.Graph at 0x1b329432520>,
#  <networkx.classes.graph.Graph at 0x1b326b2c370>,
#  <networkx.classes.graph.Graph at 0x1b32975d130>,
#  <networkx.classes.graph.Graph at 0x1b326b227c0>,
#  <networkx.classes.graph.Graph at 0x1b327b080a0>,
#  <networkx.classes.graph.Graph at 0x1b328c98c40>,
#  <networkx.classes.graph.Graph at 0x1b3296911c0>]

# %%
# %%time
# Parameters 
nsamp = 10
p = 0.05
big_dat = pd.DataFrame({"seeding method": ['random']*nsamp + ['friend']*nsamp + ['pair']*nsamp})

for i,G in enumerate(G_list):    
    try:
        print(data_paths[i])
        print(nx.number_of_nodes(G_list[i]))

        (rtran, ftran, ptran) = sim_2seed_transitivity(G_list[i], p = p, nsamp = nsamp)
        # append results as columns
        big_dat["{}_num_nodes:{}".format(data_paths[i],  nx.number_of_nodes(G_list[i]))] = rtran + ftran + ptran
    except:
        print(data_paths[i])
# Out:
# 7th_graders
# 29
# bt.csv
# 692
# email_company
# 167
# Enron
# 36692
# fb_friends.csv
# 800
# high_tech_company
# 21
# Karate
# 34
# kidnappings
# 351
# kor.2015.mers.1.00
# 186
# law_firm
# 71
# moreno_taro
# 22
# physician_trust
# 241
# sgp.2003.sars.1.00
# 172
# swingers
# 96
# uni_email
# 1133
# usa.2009.flu.1.00
# 286
# usa.2020.covid.6.00
# 92
# Wall time: 28min

# %%
big_dat.to_csv("2seedTransivityData.csv")

# %%
big_dat
# Out:
#    seeding method  7th_graders_num_nodes:29  email_company_num_nodes:167  \
# 0          random                       0.0                     0.002808
# 1          random                       0.0                     0.003001
# 2          random                       0.0                     0.001266
# 3          random                       0.0                     0.000640
# 4          random                       0.0                     0.001057
# 5          random                       0.0                     0.000771
# 6          random                       0.0                     0.000179
# 7          random                       0.0                     0.001484
# 8          random                       0.0                     0.000936
# 9          random                       0.0                     0.000533
# 10         friend                       0.0                     0.004985
# 11         friend                       0.0                     0.006013
# 12         friend                       0.0                     0.002861
# 13         friend                       0.0                     0.003326
# 14         friend                       0.0                     0.002614
# 15         friend                       0.0                     0.002584
# 16         friend                       0.0                     0.002003
# 17         friend                       0.0                     0.005334
# 18         friend                       0.0                     0.003021
# 19         friend                       0.0                     0.001794
# 20           pair                       0.0                     0.002677
# 21           pair                       0.0                     0.002982
# 22           pair                       0.0                     0.002051
# 23           pair                       0.0                     0.001988
# 24           pair                       0.0                     0.002992
# 25           pair                       0.0                     0.001139
# 26           pair                       0.0                     0.002565
# 27           pair                       0.0                     0.001901
# 28           pair                       0.0                     0.002221
# 29           pair                       0.0                     0.001280
#
#     high_tech_company_num_nodes:21  law_firm_num_nodes:71  \
# 0                              0.0               0.000523
# 1                              0.0               0.000000
# 2                              0.0               0.000000
# 3                              0.0               0.000425
# 4                              0.0               0.000000
# 5                              0.0               0.000523
# 6                              0.0               0.002025
# 7                              0.0               0.000914
# 8                              0.0               0.000882
# 9                              0.0               0.001698
# 10                             0.0               0.001339
# 11                             0.0               0.000000
# 12                             0.0               0.000816
# 13                             0.0               0.000490
# 14                             0.0               0.000000
# 15                             0.0               0.000980
# 16                             0.0               0.000588
# 17                             0.0               0.000718
# 18                             0.0               0.000000
# 19                             0.0               0.000882
# 20                             0.0               0.000653
# 21                             0.0               0.000261
# 22                             0.0               0.000588
# 23                             0.0               0.000294
# 24                             0.0               0.000196
# 25                             0.0               0.000490
# 26                             0.0               0.000457
# 27                             0.0               0.000523
# 28                             0.0               0.000849
# 29                             0.0               0.000359
#
#     moreno_taro_num_nodes:22  physician_trust_num_nodes:241  \
# 0                        0.0                       0.000623
# 1                        0.0                       0.000125
# 2                        0.0                       0.001246
# 3                        0.0                       0.000872
# 4                        0.0                       0.000125
# 5                        0.0                       0.000374
# 6                        0.0                       0.001620
# 7                        0.0                       0.000249
# 8                        0.0                       0.000000
# 9                        0.0                       0.000498
# 10                       0.0                       0.000872
# 11                       0.0                       0.001121
# 12                       0.0                       0.000872
# 13                       0.0                       0.002492
# 14                       0.0                       0.001744
# 15                       0.0                       0.000748
# 16                       0.0                       0.001495
# 17                       0.0                       0.000374
# 18                       0.0                       0.000748
# 19                       0.0                       0.001744
# 20                       0.0                       0.000498
# 21                       0.0                       0.002118
# 22                       0.0                       0.000872
# 23                       0.0                       0.001620
# 24                       0.0                       0.002243
# 25                       0.0                       0.001620
# 26                       0.0                       0.001994
# 27                       0.0                       0.002492
# 28                       0.0                       0.001744
# 29                       0.0                       0.000748
#
#     uni_email_num_nodes:1133
# 0                   0.000342
# 1                   0.000311
# 2                   0.000508
# 3                   0.000436
# 4                   0.000093
# 5                   0.000280
# 6                   0.000550
# 7                   0.000145
# 8                   0.000664
# 9                   0.000685
# 10                  0.002230
# 11                  0.001857
# 12                  0.002033
# 13                  0.000985
# 14                  0.001483
# 15                  0.000757
# 16                  0.001224
# 17                  0.001079
# 18                  0.000965
# 19                  0.001981
# 20                  0.001805
# 21                  0.001452
# 22                  0.001068
# 23                  0.000944
# 24                  0.000633
# 25                  0.000685
# 26                  0.001286
# 27                  0.002012
# 28                  0.001214
# 29                  0.001494

# %%
G_random = []
for i, G_empirical in enumerate(G_list):
    try:
        G = nx.barabasi_albert_graph(len(G_empirical.nodes()), int(np.average(G_empirical.degree())/2))
        G_random.append(G)
    except:
        print(data_paths[i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-31c5a6c008a8> in <module>
#       1 for x in G_list:
# ----> 2     nx.barabasi_albert_graph(len(x.nodes()), int(np.average(x.degree())/2))
#
# <__array_function__ internals> in average(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in average(a, axis, weights, returned)
#     378
#     379     if weights is None:
# --> 380         avg = a.mean(axis)
#     381         scl = avg.dtype.type(a.size/avg.size)
#     382     else:
#
# ~\anaconda3\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims)
#     158             is_float16_result = True
#     159
# --> 160     ret = umr_sum(arr, axis, dtype, out, keepdims)
#     161     if isinstance(ret, mu.ndarray):
#     162         ret = um.true_divide(
#
# TypeError: cannot perform reduce with flexible type
